# %%
# imports

import pandas as pd

import requests
import os

$ conda install python-citybikes

# %% [markdown]
#  ## On terminal creating env variable
# export FOURSQUARE_API_KEY='YOUR_API_KEY'
#
# echo $FOURSQUARE_API_KEY

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
## Using Foursquare to find bike stations with a small radius (1000m) for all the bike stations in NYC.

   ## I had sent a request to Foursquare using the codes below and I chose New York City
    ## On terminal creating env variable
export FOURSQUARE_API_KEY='YOUR_API_KEY'
    
echo $FOURSQUARE_API_KEY


# Get information about bike stations

# imports

## Importing to notebook
import requests
import os

#set the keys
foursquare_id = os.environ[""]
foursquare_secret = os.environ[""]

## Step 1.) os.environ loads the dictionary with environment variables where os.environ.keys() 
## are all variable names
api_key = os.environ[""]
    
## Step 2.) Assigning a location
location = "NewYorkCity,USA"

## Step 3.) URL for the Foursquar API

import requests

url = "https://api.foursquare.com/v3/places/search?query=bike%20stations&near=New%20York%20City"

headers = {
    "accept": "application/json",
    "Authorization": "your_api_key"
}

response = requests.get(url, headers=headers)

print(response.text)

## 

curl --request GET \
     --url 'https://api.foursquare.com/v3/places/search?query=bike%20stations&near=New%20York%20City' \
     --header 'Authorization: your_api_key' \
     --header 'accept: application/json'

## Step 4.) Parsing through Foursquar API response

{
  "results": [
    {
      "fsq_id": "51a9070f698f1d8a4bcfc84d",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 1127,
      "geocodes": {
        "drop_off": {
          "latitude": 40.739076,
          "longitude": -73.979752
        },
        "main": {
          "latitude": 40.73897,
          "longitude": -73.979796
        },
        "roof": {
          "latitude": 40.73897,
          "longitude": -73.979796
        }
      },
      "link": "/v3/places/51a9070f698f1d8a4bcfc84d",
      "location": {
        "address": "E 25TH St",
        "census_block": "360610066006000",
        "country": "US",
        "dma": "New York",
        "formatted_address": "E 25TH St, New York, NY 10010",
        "locality": "New York",
        "postcode": "10010",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "4c8fea62160ea0938440d2fc",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 863,
      "geocodes": {
        "drop_off": {
          "latitude": 40.73514,
          "longitude": -73.991858
        },
        "main": {
          "latitude": 40.734968,
          "longitude": -73.992128
        },
        "roof": {
          "latitude": 40.734968,
          "longitude": -73.992128
        }
      },
      "link": "/v3/places/4c8fea62160ea0938440d2fc",
      "location": {
        "address": "E 14TH St",
        "census_block": "360610061001000",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "E 14TH St, New York, NY 10003",
        "locality": "New York",
        "postcode": "10003",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51a356528bbd3ff0e557c61a",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 291,
      "geocodes": {
        "drop_off": {
          "latitude": 40.742354,
          "longitude": -73.989423
        },
        "main": {
          "latitude": 40.742488,
          "longitude": -73.989367
        },
        "roof": {
          "latitude": 40.742488,
          "longitude": -73.989367
        }
      },
      "link": "/v3/places/51a356528bbd3ff0e557c61a",
      "location": {
        "address": "W 24TH St",
        "census_block": "360610058002002",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "W 24TH St, New York, NY 10010",
        "locality": "New York",
        "postcode": "10010",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "518262a77dd2568158ec4e62",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 329,
      "geocodes": {
        "drop_off": {
          "latitude": 40.740571,
          "longitude": -73.989528
        },
        "main": {
          "latitude": 40.740371,
          "longitude": -73.989851
        },
        "roof": {
          "latitude": 40.740371,
          "longitude": -73.989851
        }
      },
      "link": "/v3/places/518262a77dd2568158ec4e62",
      "location": {
        "address": "E 22ND St",
        "census_block": "360610056003001",
        "country": "US",
        "cross_street": "E 22nd St",
        "dma": "New York",
        "formatted_address": "E 22ND St (E 22nd St), New York, NY 10010",
        "locality": "New York",
        "postcode": "10010",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51a3fb91498e8fe1acfe75c9",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 519,
      "geocodes": {
        "drop_off": {
          "latitude": 40.744226,
          "longitude": -73.998013
        },
        "main": {
          "latitude": 40.744359,
          "longitude": -73.997957
        },
        "roof": {
          "latitude": 40.744359,
          "longitude": -73.997957
        }
      },
      "link": "/v3/places/51a3fb91498e8fe1acfe75c9",
      "location": {
        "address": "W 22ND St",
        "census_block": "360610091003000",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "W 22ND St, New York, NY 10011",
        "locality": "New York",
        "postcode": "10011",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "5038b7b9e4b0fc35e3f4101c",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 540,
      "geocodes": {
        "drop_off": {
          "latitude": 40.737239,
          "longitude": -73.992436
        },
        "main": {
          "latitude": 40.737334,
          "longitude": -73.992396
        },
        "roof": {
          "latitude": 40.737334,
          "longitude": -73.992396
        }
      },
      "link": "/v3/places/5038b7b9e4b0fc35e3f4101c",
      "location": {
        "address": "E 16TH St",
        "census_block": "360610052002004",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "E 16TH St, New York, NY 10011",
        "locality": "New York",
        "postcode": "10011",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "519ba4c8abd896bd0ed95065",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 576,
      "geocodes": {
        "drop_off": {
          "latitude": 40.740953,
          "longitude": -73.986127
        },
        "main": {
          "latitude": 40.741066,
          "longitude": -73.986079
        },
        "roof": {
          "latitude": 40.741066,
          "longitude": -73.986079
        }
      },
      "link": "/v3/places/519ba4c8abd896bd0ed95065",
      "location": {
        "address": "E 24TH St",
        "census_block": "360610056001005",
        "country": "US",
        "dma": "New York",
        "formatted_address": "E 24TH St, New York, NY 10010",
        "locality": "New York",
        "postcode": "10010",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51a371818bbd3ff0e56f2cf4",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 583,
      "geocodes": {
        "drop_off": {
          "latitude": 40.746904,
          "longitude": -73.988706
        },
        "main": {
          "latitude": 40.746603,
          "longitude": -73.98883
        },
        "roof": {
          "latitude": 40.746603,
          "longitude": -73.98883
        }
      },
      "link": "/v3/places/51a371818bbd3ff0e56f2cf4",
      "location": {
        "address": "W 29TH St",
        "census_block": "360610076002002",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "W 29TH St, New York, NY 10001",
        "locality": "New York",
        "postcode": "10001",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51a3d3717dd246514e7391b1",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 593,
      "geocodes": {
        "drop_off": {
          "latitude": 40.73336,
          "longitude": -73.995544
        },
        "main": {
          "latitude": 40.74499,
          "longitude": -73.986626
        },
        "roof": {
          "latitude": 40.74499,
          "longitude": -73.986626
        }
      },
      "link": "/v3/places/51a3d3717dd246514e7391b1",
      "location": {
        "address": "5TH Ave",
        "census_block": "360610074003002",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "5TH Ave, New York, NY 10009",
        "locality": "New York",
        "postcode": "10009",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    },
    {
      "fsq_id": "51a374a58bbd3ff0e571a262",
      "categories": [
        {
          "id": 19002,
          "name": "Bike Rental",
          "icon": {
            "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_",
            "suffix": ".png"
          }
        }
      ],
      "chains": [
        {
          "id": "67cfc887-fd56-4837-b907-b69221ff8b5b",
          "name": "Citi Bike"
        }
      ],
      "distance": 747,
      "geocodes": {
        "drop_off": {
          "latitude": 40.740621,
          "longitude": -73.983935
        },
        "main": {
          "latitude": 40.740742,
          "longitude": -73.984102
        },
        "roof": {
          "latitude": 40.740742,
          "longitude": -73.984102
        }
      },
      "link": "/v3/places/51a374a58bbd3ff0e571a262",
      "location": {
        "address": "Lexington Ave",
        "census_block": "360610068001003",
        "country": "US",
        "cross_street": "",
        "dma": "New York",
        "formatted_address": "Lexington Ave, New York, NY 10016",
        "locality": "New York",
        "postcode": "10016",
        "region": "NY"
      },
      "name": "Citi Bike Station",
      "related_places": {},
      "timezone": "America/New_York"
    }
  ],
  "context": {
    "geo_bounds": {
      "circle": {
        "center": {
          "latitude": 40.742185,
          "longitude": -73.992602
        },
        "radius": 6310
      }
    }
  }
}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
## Putting my parsed results into a database

## Importing required packages
import pandas as pd

## Putting my parsed restuls into a Dataframe
## Pandas dataframe

dataFrame1 = pd.DataFrame({'Bike Stations': ['Lexington Ave', '5TH Ave', 'W 29TH St', 'W 29TH St'],  
                    'Name': ['Citi Bike Station', 'Citi Bike Station', 'Citi Bike Station', 'Citi Bike Station'],  
                    'Number of Bikes':[12,19,0,13]})  
  
  
frames = [dataFrame1]  
  
result = pd.concat(frames)  
display(result) 

# Dictionary as input to DataFrame 
my_dict = {1: ['1', '3'], 2: ['1', '2'], 3: ['2', '4']}
print(pd.DataFrame(my_dict))

# Take a Series as input to DataFrame
my_series = pd.Series({"Location":"Bike Stations","libraries"})
print(pd.DataFrame(my_series))

## This will transform it into a JSON file/format 
first_json = pd.read_json(data)
first_json.head()

## this converts to database that will go on SQlite3
first_json = pd.json_normalize(res_json)
first_json.head()

## Results in JSON format which will be converted into a database
#file path for sqlite this for dataframe 1
import sqlite3
conn = sqlite3.connect('/Users/ibadetazemi/Desktop/Data Science/bikes.db')
first_json.to_sql('CityBike', conn, if_exists='replace', index=False)

## Putting my parsed results into a dataframe
import pandas as pd 
import numpy as np

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
## Request sent to Yelp with a small radius (1000m) for all the bike stations in NYC

import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=40.734786&longitude=-74.050444&radius=1000&categories=bike%20stations&sort_by=best_match&limit=10"

headers = {
    "accept": "application/json",
    "Authorization": "bearer 6sYnkRmhQwcWwnjP65O1cooTR7jDGlGkpodCYo3XlCA5qNCyh4-boa8AGkF42q_Jcoahmt_2zKz6sdimDUO7lBbINPl2OutHAv8EVRiBYFYROoB7CnZTqvKo9kueZHYx"
}

response = requests.get(url, headers=headers)

print(response.text)

# Response

{
  "businesses": [
    {
      "id": "hRsaPTimZY8VPixrrQa8NQ",
      "alias": "box-cafe-jersey-city",
      "name": "Box Cafe",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/6x-ToaeB3EhdfyBThyxJYQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/box-cafe-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 25,
      "categories": [
        {
          "alias": "cafes",
          "title": "Cafes"
        },
        {
          "alias": "coffee",
          "title": "Coffee & Tea"
        },
        {
          "alias": "french",
          "title": "French"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.733214,
        "longitude": -74.051486
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "location": {
        "address1": "115 Palisade Ave",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07306",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "115 Palisade Ave",
          "Jersey City, NJ 07306"
        ]
      },
      "phone": "+12014289475",
      "display_phone": "(201) 428-9475",
      "distance": 197.0140552737638
    },
    {
      "id": "L3Xlg3wJSDjbtRYz3ps93w",
      "alias": "low-fidelity-jersey-city",
      "name": "Low Fidelity",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/KW_Avo-3lfdHyA0Q5w8p8g/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/low-fidelity-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 183,
      "categories": [
        {
          "alias": "cocktailbars",
          "title": "Cocktail Bars"
        },
        {
          "alias": "pizza",
          "title": "Pizza"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.73977,
        "longitude": -74.04679
      },
      "transactions": [
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "328 Palisade Ave",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07307",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "328 Palisade Ave",
          "Jersey City, NJ 07307"
        ]
      },
      "phone": "+12017953600",
      "display_phone": "(201) 795-3600",
      "distance": 650.1474936370203
    },
    {
      "id": "R1mLakJBtmK-KETUuLaGaA",
      "alias": "rumba-cubana-jersey-city",
      "name": "Rumba Cubana",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/dHlqKMIiYubgeukfXJfvTw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/rumba-cubana-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 517,
      "categories": [
        {
          "alias": "cuban",
          "title": "Cuban"
        },
        {
          "alias": "bars",
          "title": "Bars"
        },
        {
          "alias": "caribbean",
          "title": "Caribbean"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.727373308159954,
        "longitude": -74.04381749999845
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "235 Pavonia Ave",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07302",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "235 Pavonia Ave",
          "Jersey City, NJ 07302"
        ]
      },
      "phone": "+12018784400",
      "display_phone": "(201) 878-4400",
      "distance": 995.5679054345183
    },
    {
      "id": "429OdBIPFsYTrS705N-n0Q",
      "alias": "veloce-specialty-sandwiches-jersey-city",
      "name": "Veloce Specialty Sandwiches",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/cfIUcCyfHs89Qe-7U8XfZw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/veloce-specialty-sandwiches-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 61,
      "categories": [
        {
          "alias": "sandwiches",
          "title": "Sandwiches"
        },
        {
          "alias": "salad",
          "title": "Salad"
        },
        {
          "alias": "italian",
          "title": "Italian"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.73671,
        "longitude": -74.051595
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "457 Baldwin Ave",
        "address2": "",
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07306",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "457 Baldwin Ave",
          "Jersey City, NJ 07306"
        ]
      },
      "phone": "+12012679555",
      "display_phone": "(201) 267-9555",
      "distance": 228.3373167104718
    },
    {
      "id": "LSMfKvER1s42GV_BV4nELA",
      "alias": "pico-taco-jersey-city",
      "name": "Pico Taco",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/9dZBinzDjV8B08MpeNoKNw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/pico-taco-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 111,
      "categories": [
        {
          "alias": "tacos",
          "title": "Tacos"
        },
        {
          "alias": "breakfast_brunch",
          "title": "Breakfast & Brunch"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7350228,
        "longitude": -74.0528913
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "418 Baldwin Ave",
        "address2": null,
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07306",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "418 Baldwin Ave",
          "Jersey City, NJ 07306"
        ]
      },
      "phone": "+12019422967",
      "display_phone": "(201) 942-2967",
      "distance": 207.8750862611983
    },
    {
      "id": "dfh4IK_KOa_giRjrRaHg0Q",
      "alias": "white-star-bar-jersey-city",
      "name": "White Star Bar",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/0GUND_h6E5OM-Vu2qGpbOw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/white-star-bar-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 513,
      "categories": [
        {
          "alias": "burgers",
          "title": "Burgers"
        },
        {
          "alias": "newamerican",
          "title": "American (New)"
        },
        {
          "alias": "cocktailbars",
          "title": "Cocktail Bars"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.72794,
        "longitude": -74.04991
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "230 Brunswick St",
        "address2": "",
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07302",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "230 Brunswick St",
          "Jersey City, NJ 07302"
        ]
      },
      "phone": "+12016539234",
      "display_phone": "(201) 653-9234",
      "distance": 759.8066980612202
    },
    {
      "id": "J3xSIWSznPe9Ii8B_HOksA",
      "alias": "ed-and-marys-jersey-city",
      "name": "Ed & Mary's",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Qe7a18y01fMS7E1FjmzDZA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/ed-and-marys-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 96,
      "categories": [
        {
          "alias": "tradamerican",
          "title": "American (Traditional)"
        },
        {
          "alias": "bars",
          "title": "Bars"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.7287270058542,
        "longitude": -74.0465716965112
      },
      "transactions": [
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "174 Coles St",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07307",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "174 Coles St",
          "Jersey City, NJ 07307"
        ]
      },
      "phone": "+12018395604",
      "display_phone": "(201) 839-5604",
      "distance": 757.7373937022869
    },
    {
      "id": "3rZwXDjkyDLAHNSdPUI5WA",
      "alias": "korai-kitchen-jersey-city",
      "name": "Korai Kitchen",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/czVFamLw-OlToyBTn_pCcQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/korai-kitchen-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 325,
      "categories": [
        {
          "alias": "bangladeshi",
          "title": "Bangladeshi"
        },
        {
          "alias": "halal",
          "title": "Halal"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.733896,
        "longitude": -74.059151
      },
      "transactions": [
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "576 Summit Ave",
        "address2": null,
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07306",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "576 Summit Ave",
          "Jersey City, NJ 07306"
        ]
      },
      "phone": "+12017216566",
      "display_phone": "(201) 721-6566",
      "distance": 739.3564792156205
    },
    {
      "id": "BNsKXLDL0pM_IaAR_LR7bw",
      "alias": "the-hamilton-inn-jersey-city",
      "name": "The Hamilton Inn",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/i2NmxmqQpQ8qN5u3F0YUlQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/the-hamilton-inn-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 811,
      "categories": [
        {
          "alias": "newamerican",
          "title": "American (New)"
        },
        {
          "alias": "desserts",
          "title": "Desserts"
        },
        {
          "alias": "breakfast_brunch",
          "title": "Breakfast & Brunch"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7289398377141,
        "longitude": -74.0446714764976
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "price": "$$",
      "location": {
        "address1": "708 Jersey Ave",
        "address2": "",
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07302",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "708 Jersey Ave",
          "Jersey City, NJ 07302"
        ]
      },
      "phone": "+12018395818",
      "display_phone": "(201) 839-5818",
      "distance": 811.8874202035761
    },
    {
      "id": "-Z0t37wEuDh0f8kV3IDcUA",
      "alias": "jersey-social-jersey-city-2",
      "name": "Jersey Social",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/dSYJrTN7ruwVSkjw1n7aGQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/jersey-social-jersey-city-2?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 69,
      "categories": [
        {
          "alias": "bars",
          "title": "Bars"
        },
        {
          "alias": "newamerican",
          "title": "American (New)"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.73462,
        "longitude": -74.04468
      },
      "transactions": [
        "pickup",
        "delivery"
      ],
      "location": {
        "address1": "837 Jersey Ave",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07310",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "837 Jersey Ave",
          "Jersey City, NJ 07310"
        ]
      },
      "phone": "+12012227447",
      "display_phone": "(201) 222-7447",
      "distance": 488.2133529215606
    }
  ],
  "total": 179,
  "region": {
    "center": {
      "longitude": -74.050444,
      "latitude": 40.734786
    }
  }
}

## Sending request to Yelp with a radius (1000m) for all the bike stations in NYC
curl --request GET \
     --url 'https://api.yelp.com/v3/businesses/search?location=New%20York%20City&term=city%20bikes&radius=1000&categories=bike%20stations&sort_by=best_match&limit=20' \
     --header 'Authorization: your_api_key' \
     --header 'accept: application/json'

## Parsing through response

{
  "businesses": [
    {
      "id": "19o2Oy83HtFt0kOmsSzTpg",
      "alias": "bicycle-station-brooklyn",
      "name": "Bicycle Station",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/LjH0wpc31Kwsbj5Geyq8pg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bicycle-station-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 181,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.696367,
        "longitude": -73.972663
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "171 Park Ave",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11205",
        "country": "US",
        "state": "NY",
        "display_address": [
          "171 Park Ave",
          "Brooklyn, NY 11205"
        ]
      },
      "phone": "+17186380300",
      "display_phone": "(718) 638-0300",
      "distance": 1303.1411706144397
    },
    {
      "id": "CVLRrxr1ZpHbr_Au3pKoCw",
      "alias": "atlantic-bicycles-brooklyn-2",
      "name": "Atlantic Bicycles",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/68aXVfDvCyPCjshPfjPWyg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/atlantic-bicycles-brooklyn-2?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 35,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.688618,
        "longitude": -73.989883
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "278 Atlantic Ave",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11201",
        "country": "US",
        "state": "NY",
        "display_address": [
          "278 Atlantic Ave",
          "Brooklyn, NY 11201"
        ]
      },
      "phone": "+17186259633",
      "display_phone": "(718) 625-9633",
      "distance": 2231.7745352903503
    },
    {
      "id": "pD9piFqDaqSBhYRod3WJ6w",
      "alias": "brooklyn-bike-peddler-brooklyn",
      "name": "Brooklyn Bike Peddler",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/07LjLFRawbswvJBfdr75Lw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/brooklyn-bike-peddler-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 57,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7159518,
        "longitude": -73.9494802
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "636 Lorimer St",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11211",
        "country": "US",
        "state": "NY",
        "display_address": [
          "636 Lorimer St",
          "Brooklyn, NY 11211"
        ]
      },
      "phone": "+13477992014",
      "display_phone": "(347) 799-2014",
      "distance": 2695.388340470003
    },
    {
      "id": "E11jtpLW6c4eKkTJWcD1XA",
      "alias": "bfold-folding-bicycles-new-york",
      "name": "Bfold Folding Bicycles",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/ZXTKksR1po7xSHHhF1tv9Q/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bfold-folding-bicycles-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 101,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.73211,
        "longitude": -73.98676
      },
      "transactions": [],
      "price": "$$$",
      "location": {
        "address1": "224 E 13th St",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10003",
        "country": "US",
        "state": "NY",
        "display_address": [
          "224 E 13th St",
          "New York, NY 10003"
        ]
      },
      "phone": "+12125297247",
      "display_phone": "(212) 529-7247",
      "distance": 2862.6759327749996
    },
    {
      "id": "CRGUiRELrqw2B4X2lW8SLw",
      "alias": "ride-brooklyn-brooklyn",
      "name": "Ride Brooklyn",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-2-sliS-vRWvrF8xsJzywg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/ride-brooklyn-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 257,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.680846,
        "longitude": -73.975861
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "468 Bergen St",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11217",
        "country": "US",
        "state": "NY",
        "display_address": [
          "468 Bergen St",
          "Brooklyn, NY 11217"
        ]
      },
      "phone": "+17188577433",
      "display_phone": "(718) 857-7433",
      "distance": 2923.518373049888
    },
    {
      "id": "Mh4ZWZMgahAI_1xu-0VXWw",
      "alias": "silk-road-cycles-brooklyn",
      "name": "Silk Road Cycles",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PlCgrQjvOIJqqe-y2XcuYA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/silk-road-cycles-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 110,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.72723,
        "longitude": -73.95686
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "76 Franklin St",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11222",
        "country": "US",
        "state": "NY",
        "display_address": [
          "76 Franklin St",
          "Brooklyn, NY 11222"
        ]
      },
      "phone": "+17183892222",
      "display_phone": "(718) 389-2222",
      "distance": 2933.928193311125
    },
    {
      "id": "ukPP3m3yqEuSBQiCK01cXQ",
      "alias": "r-and-a-cycles-brooklyn",
      "name": "R&A Cycles",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/idwLiiZn96nxu27kTOXJ9A/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/r-and-a-cycles-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 266,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 2.5,
      "coordinates": {
        "latitude": 40.6794,
        "longitude": -73.97828
      },
      "transactions": [],
      "price": "$$$$",
      "location": {
        "address1": "105 5th Ave",
        "address2": null,
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11217",
        "country": "US",
        "state": "NY",
        "display_address": [
          "105 5th Ave",
          "Brooklyn, NY 11217"
        ]
      },
      "phone": "+17186380479",
      "display_phone": "(718) 638-0479",
      "distance": 3070.173082276442
    },
    {
      "id": "AWLXZPJbKnh_2vWuFvMbpA",
      "alias": "bs-bikes-brooklyn",
      "name": "B's Bikes",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/JWDc3bBbL223A8EtkfBPzw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bs-bikes-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 254,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.72277,
        "longitude": -73.94835
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "262 Driggs Ave",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11222",
        "country": "US",
        "state": "NY",
        "display_address": [
          "262 Driggs Ave",
          "Brooklyn, NY 11222"
        ]
      },
      "phone": "+17183491212",
      "display_phone": "(718) 349-1212",
      "distance": 3136.948075295253
    },
    {
      "id": "AA7U-jkHEWH3nvwncDsQxw",
      "alias": "waterfront-bicycle-shop-new-york",
      "name": "Waterfront Bicycle Shop",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/L8QUQWbcLCyhTiCpNycvDQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/waterfront-bicycle-shop-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 102,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4.5,
      "coordinates": {
        "latitude": 40.7328461,
        "longitude": -74.0101625
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "391 West St",
        "address2": null,
        "address3": "",
        "city": "New York",
        "zip_code": "10014",
        "country": "US",
        "state": "NY",
        "display_address": [
          "391 West St",
          "New York, NY 10014"
        ]
      },
      "phone": "+12124142453",
      "display_phone": "(212) 414-2453",
      "distance": 3884.3806682448535
    },
    {
      "id": "gyd5P7rsmQJNVi2iefqxBQ",
      "alias": "bicycle-habitat-new-york",
      "name": "Bicycle Habitat",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wF8udjaaRL1B5lyCYQH4Dg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bicycle-habitat-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 293,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 3.5,
      "coordinates": {
        "latitude": 40.74443,
        "longitude": -73.99563
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "228 7th Ave",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10011",
        "country": "US",
        "state": "NY",
        "display_address": [
          "228 7th Ave",
          "New York, NY 10011"
        ]
      },
      "phone": "+12122066949",
      "display_phone": "(212) 206-6949",
      "distance": 4391.799427097121
    },
    {
      "id": "gtftVWdYwAogNQcQH6NmFA",
      "alias": "fulton-bikes-brooklyn-3",
      "name": "Fulton Bikes",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/rPejecygB4FXoqAtr1ukIQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/fulton-bikes-brooklyn-3?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 76,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.6795748,
        "longitude": -73.93756762884517
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "1580 Fulton St",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11213",
        "country": "US",
        "state": "NY",
        "display_address": [
          "1580 Fulton St",
          "Brooklyn, NY 11213"
        ]
      },
      "phone": "+17187782887",
      "display_phone": "(718) 778-2887",
      "distance": 4647.247722877865
    },
    {
      "id": "QcV0baz6V_d6AJ7mi4WE7w",
      "alias": "rollgood-electric-bikes-and-scooters-new-york",
      "name": "Rollgood Electric Bikes & Scooters",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/exxRTTJHm0Gatx6lZOEZ2Q/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/rollgood-electric-bikes-and-scooters-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 20,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 3,
      "coordinates": {
        "latitude": 40.75059,
        "longitude": -73.98435
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "16 W 37th St",
        "address2": null,
        "address3": "",
        "city": "New York",
        "zip_code": "10018",
        "country": "US",
        "state": "NY",
        "display_address": [
          "16 W 37th St",
          "New York, NY 10018"
        ]
      },
      "phone": "+12129211166",
      "display_phone": "(212) 921-1166",
      "distance": 4871.2728388472015
    },
    {
      "id": "lv8l_FPiV0G8m8RIbFScGA",
      "alias": "bike-life-brooklyn",
      "name": "Bike Life",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/RQhf3ZycFSmAO9zbCT_I0w/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bike-life-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 53,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 2,
      "coordinates": {
        "latitude": 40.66073,
        "longitude": -73.96109
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "56 Lincoln Rd",
        "address2": "",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11225",
        "country": "US",
        "state": "NY",
        "display_address": [
          "56 Lincoln Rd",
          "Brooklyn, NY 11225"
        ]
      },
      "phone": "+13477895607",
      "display_phone": "(347) 789-5607",
      "distance": 5362.5305545257015
    },
    {
      "id": "DpAO4gzlnHI2VR4T4asN3w",
      "alias": "city-bicycles-new-york",
      "name": "City Bicycles",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Xl5svlkXjA6hcoPfvvmvvA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/city-bicycles-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 54,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7551382,
        "longitude": -73.9923058
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "307 W 38th St",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10018",
        "country": "US",
        "state": "NY",
        "display_address": [
          "307 W 38th St",
          "New York, NY 10018"
        ]
      },
      "phone": "+12125633373",
      "display_phone": "(212) 563-3373",
      "distance": 5468.093613799761
    },
    {
      "id": "serRgVkaNLDNZ2GNi1HNqQ",
      "alias": "enochs-bike-shop-new-york",
      "name": "Enoch's Bike Shop",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/5NxxzNbsiN2CYpRb7mUINQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/enochs-bike-shop-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 49,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7563595466749,
        "longitude": -73.9977292352264
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "480 10th Ave",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10018",
        "country": "US",
        "state": "NY",
        "display_address": [
          "480 10th Ave",
          "New York, NY 10018"
        ]
      },
      "phone": "+12125820620",
      "display_phone": "(212) 582-0620",
      "distance": 5708.9527864281235
    },
    {
      "id": "xbjMJpF62KrTju9Or747pA",
      "alias": "grove-street-bicycles-jersey-city-3",
      "name": "Grove Street Bicycles",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/wqf7vJWa2mAM0ivq7QjLkA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/grove-street-bicycles-jersey-city-3?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 147,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        },
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        }
      ],
      "rating": 3.5,
      "coordinates": {
        "latitude": 40.720817,
        "longitude": -74.046086
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "172 Christopher Columbus Dr",
        "address2": "",
        "address3": "",
        "city": "Jersey City",
        "zip_code": "07302",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "172 Christopher Columbus Dr",
          "Jersey City, NJ 07302"
        ]
      },
      "phone": "+12014512453",
      "display_phone": "(201) 451-2453",
      "distance": 5844.670624155545
    },
    {
      "id": "JI_FNAixoC5MN3XQBAvRQw",
      "alias": "bicycle-repairman-corp-astoria",
      "name": "Bicycle Repairman Corp",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/zT8bHgD5_KFdYnfkSpWJGQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/bicycle-repairman-corp-astoria?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 103,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.754909666955,
        "longitude": -73.9213737877671
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "40-21A 35th Ave",
        "address2": "",
        "address3": "",
        "city": "Astoria",
        "zip_code": "11101",
        "country": "US",
        "state": "NY",
        "display_address": [
          "40-21A 35th Ave",
          "Astoria, NY 11101"
        ]
      },
      "phone": "+17187060450",
      "display_phone": "(718) 706-0450",
      "distance": 7220.621541869196
    },
    {
      "id": "tBGchHdYeek7EmpG6lr8DA",
      "alias": "toga-bikes-shop-new-york",
      "name": "Toga Bikes Shop",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/WrzLhiD8drAodFsT9vn9eA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/toga-bikes-shop-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 208,
      "categories": [
        {
          "alias": "bikerentals",
          "title": "Bike Rentals"
        },
        {
          "alias": "bikes",
          "title": "Bikes"
        },
        {
          "alias": "bike_repair_maintenance",
          "title": "Bike Repair/Maintenance"
        }
      ],
      "rating": 3,
      "coordinates": {
        "latitude": 40.77481,
        "longitude": -73.98786
      },
      "transactions": [],
      "price": "$$$",
      "location": {
        "address1": "110 W End Ave",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10023",
        "country": "US",
        "state": "NY",
        "display_address": [
          "110 W End Ave",
          "New York, NY 10023"
        ]
      },
      "phone": "+12127999625",
      "display_phone": "(212) 799-9625",
      "distance": 7577.908161755883
    },
    {
      "id": "2cx89vC2poCJvQme8DcOkQ",
      "alias": "union-cycle-center-union-city",
      "name": "Union Cycle Center",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/qh04NFhAeI7A-FjyJdoBbg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/union-cycle-center-union-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 15,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.780302046532135,
        "longitude": -74.02307299999997
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "4531 Bergenline Ave",
        "address2": "",
        "address3": "",
        "city": "Union City",
        "zip_code": "07087",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "4531 Bergenline Ave",
          "Union City, NJ 07087"
        ]
      },
      "phone": "+12018638737",
      "display_phone": "(201) 863-8737",
      "distance": 8952.388940371646
    },
    {
      "id": "fj3HZYiEQWy5yDUwT_q-mQ",
      "alias": "tonys-bicycles-astoria",
      "name": "Tony's Bicycles",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/NgMiWhFWzJGPR9_KzTHtew/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/tonys-bicycles-astoria?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 121,
      "categories": [
        {
          "alias": "bikes",
          "title": "Bikes"
        }
      ],
      "rating": 4,
      "coordinates": {
        "latitude": 40.7730313548364,
        "longitude": -73.9109058580809
      },
      "transactions": [],
      "price": "$$",
      "location": {
        "address1": "35-01 23rd Ave",
        "address2": null,
        "address3": "",
        "city": "Astoria",
        "zip_code": "11105",
        "country": "US",
        "state": "NY",
        "display_address": [
          "35-01 23rd Ave",
          "Astoria, NY 11105"
        ]
      },
      "phone": "+17182783355",
      "display_phone": "(718) 278-3355",
      "distance": 9343.59537682032
    }
  ],
  "total": 158,
  "region": {
    "center": {
      "longitude": -73.97918701171875,
      "latitude": 40.706977710584276
    }
  }
}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
## (POI: Restaurants)

import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=40.734786&longitude=-74.050444&categories=restaurants&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "bearer 6sYnkRmhQwcWwnjP65O1cooTR7jDGlGkpodCYo3XlCA5qNCyh4-boa8AGkF42q_Jcoahmt_2zKz6sdimDUO7lBbINPl2OutHAv8EVRiBYFYROoB7CnZTqvKo9kueZHYx"
}

response = requests.get(url, headers=headers)

print(response.text)


## (POI: Bars)

import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=40.734786&longitude=-74.050444&categories=bars&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "bearer 6sYnkRmhQwcWwnjP65O1cooTR7jDGlGkpodCYo3XlCA5qNCyh4-boa8AGkF42q_Jcoahmt_2zKz6sdimDUO7lBbINPl2OutHAv8EVRiBYFYROoB7CnZTqvKo9kueZHYx"
}

response = requests.get(url, headers=headers)

print(response.text)

## (POI: Bars)

curl --request GET \
     --url 'https://api.yelp.com/v3/businesses/search?location=New%20York%20City&term=bars&sort_by=best_match&limit=20' \
     --header 'Authorization: bearer your_api_key' \
     --header 'accept: application/json'

## (POI: Parsed Response from bars)

{

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# ## Putting my parsed results into a database
#
# ## Importing required packages
# import pandas as pd
#
# ## This will transform my results into a JSON file/format then after I will convert to a database
# first_json = pd.read_json(data)
# first_json.head()
#
# ## This normalizes to dataframe that will go on SQlite3
#
# import pandas as pd
#
# first_json = pd.json_normalize(res_json)
# first_json.head()
#
# ## Next step is to convert my JSON file into a database that will go into SQlite database
# import sqlite3
# conn = sqlite3.connect('/Users/ibadetazemi/Desktop/Data Science/bikes.db')
# first_json.to_sql('CityBike', conn, if_exists='replace', index=False)
#
# ## Next I will try to create dataframes:
#
# ---------------------------------------
#
# ## Importing required libraries
# import numpy as np
# import pandas as pd
#
# s = pd.Series(data, index=index)
#
# ## Specify the index
# s = pd.Series(np.random.randn(5), index=['Latitude', 'Longitude', 'Bike ID'])
#
# import pandas as pd
# from IPython.display import display
#
# # DataFrame
# dataFrame1 = pd.DataFrame({'Bars': ['Paper Planes', 'Ye's Apothecary', 'The Up & Up', 'Attaboy'],
#                     'Restaurants': ['Momofuku Ko', 'Love Mamma', 'Peter Luger', 'Tapas/Small Plates'],
#
#
# frames = [dataFrame1]
#
# result = pd.concat(frames)
# display(result)
#
#
# ## Pandas Dataframe
# d = {'one': pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
#          'two': pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
#
# ## Pandas Dataframe
# df = pd.DataFrame(d)
# df
#
# ## Pandas Dataframe
# pd.DataFrame(d, index=['d', 'b', 'a'])
#
# pd.DataFrame(d, index=['d', 'b', 'a'], columns=['two', 'three'])

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation:
#
# Yelp provided me with more complete data. It provided me with more complete data
# because the information provided was helpful, customizable, accurate and usefull. And most of all it was very easy to use

# %%
Get the top 10 restaurants according to their rating

## Top 10 restaurants according to their rating request:

import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=40.734786&longitude=-74.050444&radius=1000&categories=restaurants&sort_by=rating&limit=10"

headers = {
    "accept": "application/json",
    "Authorization": "bearer your_api_key"
}

response = requests.get(url, headers=headers)

print(response.text)


## Top 10 restaurants according to their rating request:

curl --request GET \
     --url 'https://api.yelp.com/v3/businesses/search?location=new%20york%20city&categories=restaurants&sort_by=rating&limit=10' \
     --header 'Authorization: bearer ' \
     --header 'accept: application/json'

## Top 10 restaurants according to their rating response:

Anitas Restaurant
A Taste Of Italy
Taqueria Gardenias
hot-dog-jays-little-falls
ME Mediterranean Eatery
First Wok Chinese Restaurant
Camellia Milk Tea
Halal Cart
Pistache NYC
John's Market


{
  "businesses": [
    {
      "id": "Z899_gGOadcPjr1RqyAgMA",
      "alias": "anitas-restaurant-jersey-city",
      "name": "Anitas Restaurant",
      "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/smvtXK3M469Tb7m_eb37bQ/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/anitas-restaurant-jersey-city?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 6,
      "categories": [
        {
          "alias": "salvadoran",
          "title": "Salvadoran"
        },
        {
          "alias": "mexican",
          "title": "Mexican"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.72518153692665,
        "longitude": -74.06437211576299
      },
      "transactions": [],
      "location": {
        "address1": "292 Summit Ave",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07306",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "292 Summit Ave",
          "Jersey City, NJ 07306"
        ]
      },
      "phone": "+12018395732",
      "display_phone": "(201) 839-5732",
      "distance": 7459.313335191987
    },
    {
      "id": "cXXmLxs_pRwBZa1pVW58Aw",
      "alias": "a-taste-of-italy-bronx",
      "name": "A Taste Of Italy",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/zYAGj9MDpIefs1vi_FTzvg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/a-taste-of-italy-bronx?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 5,
      "categories": [
        {
          "alias": "delis",
          "title": "Delis"
        },
        {
          "alias": "italian",
          "title": "Italian"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.845624055040034,
        "longitude": -73.7856575
      },
      "transactions": [],
      "location": {
        "address1": "250 City Island Ave",
        "address2": "",
        "address3": null,
        "city": "Bronx",
        "zip_code": "10464",
        "country": "US",
        "state": "NY",
        "display_address": [
          "250 City Island Ave",
          "Bronx, NY 10464"
        ]
      },
      "phone": "+17188850919",
      "display_phone": "(718) 885-0919",
      "distance": 22432.872915820222
    },
    {
      "id": "0K6Ba-MPQ-vACYap2abP0g",
      "alias": "taqueria-gardenias-jersey-city-2",
      "name": "Taqueria Gardenias",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/t1ew36RHfGRVKcWFDvQblA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/taqueria-gardenias-jersey-city-2?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 5,
      "categories": [
        {
          "alias": "foodtrucks",
          "title": "Food Trucks"
        },
        {
          "alias": "mexican",
          "title": "Mexican"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.72202,
        "longitude": -74.04651
      },
      "transactions": [],
      "location": {
        "address1": "",
        "address2": "",
        "address3": null,
        "city": "Jersey City",
        "zip_code": "07302",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "Jersey City, NJ 07302"
        ]
      },
      "phone": "+12014814138",
      "display_phone": "(201) 481-4138",
      "distance": 5763.36137834246
    },
    {
      "id": "GcA_4Uiv5RWlfkNg9n548A",
      "alias": "hot-dog-jays-little-falls",
      "name": "Hot Dog Jay's",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PkBFLYc5WIrpoojAkBCZqw/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/hot-dog-jays-little-falls?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 11,
      "categories": [
        {
          "alias": "hotdog",
          "title": "Hot Dogs"
        },
        {
          "alias": "foodtrucks",
          "title": "Food Trucks"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.88165,
        "longitude": -74.235035
      },
      "transactions": [],
      "location": {
        "address1": "65 Union Ave",
        "address2": null,
        "address3": "",
        "city": "Little Falls",
        "zip_code": "07424",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "65 Union Ave",
          "Little Falls, NJ 07424"
        ]
      },
      "phone": "",
      "display_phone": "",
      "distance": 29001.80818384995
    },
    {
      "id": "m9IqF_ZaF-IjdO6cJgESrQ",
      "alias": "me-mediterranean-eatery-new-york",
      "name": "ME Mediterranean Eatery",
      "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/b2a6nIdFkbi3HsW0yTeSGg/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/me-mediterranean-eatery-new-york?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 5,
      "categories": [
        {
          "alias": "mediterranean",
          "title": "Mediterranean"
        },
        {
          "alias": "wraps",
          "title": "Wraps"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.76174381046903,
        "longitude": -73.94957142883567
      },
      "transactions": [],
      "location": {
        "address1": "548 Main St",
        "address2": "",
        "address3": null,
        "city": "New York",
        "zip_code": "10044",
        "country": "US",
        "state": "NY",
        "display_address": [
          "548 Main St",
          "New York, NY 10044"
        ]
      },
      "phone": "",
      "display_phone": "",
      "distance": 6581.120821696627
    },
    {
      "id": "K2ClEfA_etWq59nl5OCG4A",
      "alias": "first-wok-chinese-restaurant-mount-vernon",
      "name": "First Wok Chinese Restaurant",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/VvBSZS5THjxiz0Z2_QIcBA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/first-wok-chinese-restaurant-mount-vernon?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 6,
      "categories": [
        {
          "alias": "restaurants",
          "title": "Restaurants"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.90996,
        "longitude": -73.82285
      },
      "transactions": [],
      "location": {
        "address1": "325 E 3rd St",
        "address2": "",
        "address3": "",
        "city": "Mount Vernon",
        "zip_code": "10553",
        "country": "US",
        "state": "NY",
        "display_address": [
          "325 E 3rd St",
          "Mount Vernon, NY 10553"
        ]
      },
      "phone": "+19146688982",
      "display_phone": "(914) 668-8982",
      "distance": 26119.372872041004
    },
    {
      "id": "c4gj_cbIJVKQRQFTP9pZWA",
      "alias": "camellia-milk-tea-new-york-2",
      "name": "Camellia Milk Tea",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/D0DPkj7FdzHFoNFZIdxjoA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/camellia-milk-tea-new-york-2?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 7,
      "categories": [
        {
          "alias": "coffee",
          "title": "Coffee & Tea"
        },
        {
          "alias": "foodstands",
          "title": "Food Stands"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.71546,
        "longitude": -73.99007
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "",
        "address2": "",
        "address3": "",
        "city": "New York",
        "zip_code": "10002",
        "country": "US",
        "state": "NY",
        "display_address": [
          "New York, NY 10002"
        ]
      },
      "phone": "+19179239064",
      "display_phone": "(917) 923-9064",
      "distance": 922.8547969508733
    },
    {
      "id": "3HshPoQL-av9pKOr09c5Pg",
      "alias": "halal-cart-queens-4",
      "name": "Halal Cart",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/gg7ve18A-lQLCtNQEHpjqA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/halal-cart-queens-4?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 5,
      "categories": [
        {
          "alias": "streetvendors",
          "title": "Street Vendors"
        },
        {
          "alias": "halal",
          "title": "Halal"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.7024487679412,
        "longitude": -73.8185780159879
      },
      "transactions": [],
      "location": {
        "address1": "13315 Jamaica Ave",
        "address2": "",
        "address3": null,
        "city": "Queens",
        "zip_code": "11418",
        "country": "US",
        "state": "NY",
        "display_address": [
          "13315 Jamaica Ave",
          "Queens, NY 11418"
        ]
      },
      "phone": "",
      "display_phone": "",
      "distance": 13547.837460001143
    },
    {
      "id": "1_JZHKkWQBozYQ00fephWQ",
      "alias": "pistache-nyc-brooklyn",
      "name": "Pistache NYC",
      "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/CPIHicLk8idoqUiGPDgh3Q/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/pistache-nyc-brooklyn?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 11,
      "categories": [
        {
          "alias": "catering",
          "title": "Caterers"
        },
        {
          "alias": "bakeries",
          "title": "Bakeries"
        },
        {
          "alias": "french",
          "title": "French"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.6996109,
        "longitude": -73.9479221
      },
      "transactions": [],
      "location": {
        "address1": "630 Flushing Ave",
        "address2": "Unit 806",
        "address3": "",
        "city": "Brooklyn",
        "zip_code": "11206",
        "country": "US",
        "state": "NY",
        "display_address": [
          "630 Flushing Ave",
          "Unit 806",
          "Brooklyn, NY 11206"
        ]
      },
      "phone": "+19175978387",
      "display_phone": "(917) 597-8387",
      "distance": 2759.8869929265497
    },
    {
      "id": "BIoFPijSoKJ382TDUzUTdg",
      "alias": "johns-market-city-of-orange",
      "name": "John's Market",
      "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/aIGoE-I81ZEtOsiUltzTDA/o.jpg",
      "is_closed": false,
      "url": "https://www.yelp.com/biz/johns-market-city-of-orange?adjust_creative=CHX7gyrFyJTNf0pLIkkBWA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CHX7gyrFyJTNf0pLIkkBWA",
      "review_count": 16,
      "categories": [
        {
          "alias": "italian",
          "title": "Italian"
        },
        {
          "alias": "sandwiches",
          "title": "Sandwiches"
        }
      ],
      "rating": 5,
      "coordinates": {
        "latitude": 40.7700772583485,
        "longitude": -74.2326208949089
      },
      "transactions": [],
      "price": "$",
      "location": {
        "address1": "100 S Essex Ave",
        "address2": "",
        "address3": "",
        "city": "City of Orange",
        "zip_code": "07050",
        "country": "US",
        "state": "NJ",
        "display_address": [
          "100 S Essex Ave",
          "City of Orange, NJ 07050"
        ]
      },
      "phone": "",
      "display_phone": "",
      "distance": 22459.145383920524
    }
  ],
  "total": 15000,
  "region": {
    "center": {
      "longitude": -73.97918701171875,
      "latitude": 40.706977710584276
    }
  }
}
